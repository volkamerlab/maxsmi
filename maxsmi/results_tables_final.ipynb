# %% [markdown]
# # maxsmi
# ## Analysis of results
#
# This notebook serves to analyse the results of the simulations ran on the Curta cluster.
#
# ## Prerequisites
# This notebook will run under the condition that some simulations have been run, e.g.
# ```
# (maxsmi) $ python maxsmi/full_workflow.py --task ESOL --aug-strategy-train augmentation_with_duplication --aug-nb-train 10 --aug-nb-test 10
#
# ```
#
# Have a look at the [README](https://github.com/t-kimber/maxsmi/blob/main/README.md) page for more details.

# %%
#  !pip install flake8 pycodestyle_magic
# %load_ext pycodestyle_magic
# %pycodestyle_on

# %%
from maxsmi.utils_analysis import load_results, retrieve_metric
import pandas as pd
from IPython.display import display
import matplotlib.pyplot as plt
import numpy as np

# %%
# To show the full pandas data frame with the full grid
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
TASK = "ESOL"

# %%
fine_grid = [elem for elem in range(0, 21, 1)]
coarse_grid = [elem for elem in range(0, 110, 10)]

temp_grid = [elem for elem in range(30, 110, 10)]
full_grid = fine_grid + temp_grid

# %%
def array_by_strategy(augmentation_strategy,
                      task="ESOL",
                      set_="test",
                      metric="rmse",
                      grid=full_grid):
    """
    #TODO
    """

    models = ["CONV1D", "CONV2D", "RNN"]

    if augmentation_strategy == "augmentation_maximum_estimation":
        if task == "ESOL":
            task = "ESOL_SMALL"
        result_array = np.zeros((1, len(models)))
        for i, model in enumerate(models):
            for j, augmentation_num in enumerate([10]):
                try:
                    y = retrieve_metric(
                        metric,
                        set_,
                        task,
                        augmentation_strategy,
                        augmentation_num,
                        augmentation_strategy,
                        augmentation_num,
                        model,
                    )
                except FileNotFoundError:
                    y = np.nan
                result_array[j, i] = y
    else:
        result_array = np.zeros((len(grid), len(models)))

        for i, model in enumerate(models):
            for j, augmentation_num in enumerate(grid):
                try:
                    y = retrieve_metric(
                        metric,
                        set_,
                        task,
                        augmentation_strategy,
                        augmentation_num,
                        augmentation_strategy,
                        augmentation_num,
                        model,
                    )
                except FileNotFoundError:
                    y = np.nan
                result_array[j, i] = y
    return result_array

# %%
res_without_dupl = array_by_strategy("augmentation_without_duplication",
                                     task=TASK)
res_with_dupl = array_by_strategy("augmentation_with_duplication", task=TASK)
res_with_red_dupl = array_by_strategy("augmentation_with_reduced_duplication",
                                      task=TASK)
res_max_est = array_by_strategy("augmentation_maximum_estimation", task=TASK)

# %%
full_res = np.concatenate([res_without_dupl,
                           res_with_dupl,
                           res_with_red_dupl,
                           res_max_est])

# %%
grid = full_grid

# %%
index_list = ["augmentation_without_duplication" for i in range(len(grid))] + \
             ["augmentation_with_duplication" for i in range(len(grid))] + \
             ["augmentation_with_reduced_duplication"
              for i in range(len(grid))] + \
             ["augmentation_maximum_estimation"]

index_nb = grid + \
           grid + \
           grid + \
           [10]

df = pd.DataFrame(full_res,
                  index=[index_list, index_nb],
                  columns=['CONV1D', 'CONV2D', 'RNN'])

# %%
df2 = df.style.\
    set_caption(f"Data: {TASK}").\
    format("{:.3f}").\
    background_gradient(cmap='Purples', subset=["CONV1D"]).\
    background_gradient(cmap='Greens', subset=["CONV2D"]).\
    background_gradient(cmap='Blues', subset=["RNN"]).\
    highlight_min(color="yellow")
df2
# Out:
# <style  type="text/css" >
# #T_111f374c_d8e0_11eb_bcf3_acde48001122row0_col0{
#             background-color:  #796eb2;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row0_col1{
#             background-color:  #2f974e;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row0_col2{
#             background-color:  #1967ad;
#             color:  #f1f1f1;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row1_col0,#T_111f374c_d8e0_11eb_bcf3_acde48001122row59_col0{
#             background-color:  #440981;
#             color:  #f1f1f1;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row1_col1{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row1_col2{
#             background-color:  #083370;
#             color:  #f1f1f1;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row2_col0,#T_111f374c_d8e0_11eb_bcf3_acde48001122row3_col0,#T_111f374c_d8e0_11eb_bcf3_acde48001122row31_col0,#T_111f374c_d8e0_11eb_bcf3_acde48001122row60_col0{
#             background-color:  #9692c4;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row2_col1{
#             background-color:  #94d390;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row2_col2{
#             background-color:  #0a539e;
#             color:  #f1f1f1;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row3_col1{
#             background-color:  #c7e9c0;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row3_col2{
#             background-color:  #2c7cba;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row4_col0{
#             background-color:  #b6b6d8;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row4_col1{
#             background-color:  #abdda5;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row4_col2{
#             background-color:  #3585bf;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row5_col0,#T_111f374c_d8e0_11eb_bcf3_acde48001122row34_col0{
#             background-color:  #bfc0de;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row5_col1{
#             background-color:  #b5e1ae;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row5_col2{
#             background-color:  #79b5d9;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row6_col0,#T_111f374c_d8e0_11eb_bcf3_acde48001122row36_col0,#T_111f374c_d8e0_11eb_bcf3_acde48001122row37_col0{
#             background-color:  #dcdcec;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row6_col1{
#             background-color:  #bae3b3;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row6_col2,#T_111f374c_d8e0_11eb_bcf3_acde48001122row34_col2{
#             background-color:  #7cb7da;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row7_col0{
#             background-color:  #dedeed;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row7_col1,#T_111f374c_d8e0_11eb_bcf3_acde48001122row27_col1,#T_111f374c_d8e0_11eb_bcf3_acde48001122row54_col1{
#             background-color:  #e6f5e1;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row7_col2{
#             background-color:  #8abfdd;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row8_col0,#T_111f374c_d8e0_11eb_bcf3_acde48001122row63_col0{
#             background-color:  #c1c2df;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row8_col1,#T_111f374c_d8e0_11eb_bcf3_acde48001122row13_col1,#T_111f374c_d8e0_11eb_bcf3_acde48001122row68_col1,#T_111f374c_d8e0_11eb_bcf3_acde48001122row82_col1{
#             background-color:  #dcf2d7;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row8_col2{
#             background-color:  #a5cde3;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row9_col0,#T_111f374c_d8e0_11eb_bcf3_acde48001122row38_col0,#T_111f374c_d8e0_11eb_bcf3_acde48001122row67_col0{
#             background-color:  #e6e5f1;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row9_col1,#T_111f374c_d8e0_11eb_bcf3_acde48001122row33_col1{
#             background-color:  #aadda4;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row9_col2{
#             background-color:  #b0d2e7;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row10_col0,#T_111f374c_d8e0_11eb_bcf3_acde48001122row68_col0{
#             background-color:  #e4e3f0;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row10_col1{
#             background-color:  #def2d9;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row10_col2{
#             background-color:  #afd1e7;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row11_col0{
#             background-color:  #e8e6f2;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row11_col1,#T_111f374c_d8e0_11eb_bcf3_acde48001122row50_col1,#T_111f374c_d8e0_11eb_bcf3_acde48001122row71_col1{
#             background-color:  #e9f7e5;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row11_col2,#T_111f374c_d8e0_11eb_bcf3_acde48001122row39_col2{
#             background-color:  #c7dbef;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row12_col0,#T_111f374c_d8e0_11eb_bcf3_acde48001122row19_col0,#T_111f374c_d8e0_11eb_bcf3_acde48001122row47_col0,#T_111f374c_d8e0_11eb_bcf3_acde48001122row48_col0,#T_111f374c_d8e0_11eb_bcf3_acde48001122row49_col0,#T_111f374c_d8e0_11eb_bcf3_acde48001122row78_col0{
#             background-color:  #f3f1f7;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row12_col1,#T_111f374c_d8e0_11eb_bcf3_acde48001122row24_col1,#T_111f374c_d8e0_11eb_bcf3_acde48001122row78_col1{
#             background-color:  #eaf7e6;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row12_col2,#T_111f374c_d8e0_11eb_bcf3_acde48001122row67_col2{
#             background-color:  #b9d6ea;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row13_col0,#T_111f374c_d8e0_11eb_bcf3_acde48001122row40_col0,#T_111f374c_d8e0_11eb_bcf3_acde48001122row79_col0{
#             background-color:  #efedf5;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row13_col2{
#             background-color:  #c6dbef;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row14_col0{
#             background-color:  #eae8f2;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row14_col1,#T_111f374c_d8e0_11eb_bcf3_acde48001122row51_col1{
#             background-color:  #eef8ea;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row14_col2{
#             background-color:  #c3daee;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row15_col0{
#             background-color:  #eeecf5;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row15_col1{
#             background-color:  #f4fbf1;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row15_col2{
#             background-color:  #d0e1f2;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row16_col0,#T_111f374c_d8e0_11eb_bcf3_acde48001122row74_col0{
#             background-color:  #eeecf4;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row16_col1{
#             background-color:  #e5f5e0;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48001122row16_col2{
#             background-color:  #b2d2e8;
#             color:  #000000;
#         }#T_111f374c_d8e0_11eb_bcf3_acde48

# %%
def best_strategy_per_model(model, dataframe):
    """
    #TODO
    """
    return (dataframe.iloc[dataframe[model].argmin()].name,
            np.round(dataframe[model].min(), 3))

# %%
print(best_strategy_per_model("CONV1D", df),
      best_strategy_per_model("CONV2D", df),
      best_strategy_per_model("RNN", df))
# Out:
# (('augmentation_with_reduced_duplication', 70), 0.569) (('augmentation_with_reduced_duplication', 14), 0.631) (('augmentation_with_duplication', 70), 0.589)
