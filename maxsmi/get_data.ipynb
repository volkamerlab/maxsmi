# %% [markdown]
# # Get open source data
#
# Get the benchmark data sets from [MoleculeNet](http://moleculenet.ai/datasets-1).

# %%
from pathlib import Path
import pandas as pd

# %%
HERE = Path(_dh[-1])
DATA = HERE / "data"

# %%
data = pd.read_csv(f'{DATA}/ESOL/delaney-processed.csv')

# %%
data
# Out:
#          Compound ID  ESOL predicted log solubility in mols per litre  \
# 0          Amigdalin                                           -0.974
# 1           Fenfuram                                           -2.885
# 2             citral                                           -2.579
# 3             Picene                                           -6.618
# 4          Thiophene                                           -2.232
# ...              ...                                              ...
# 1123       halothane                                           -2.608
# 1124          Oxamyl                                           -0.908
# 1125       Thiometon                                           -3.323
# 1126  2-Methylbutane                                           -2.245
# 1127        Stirofos                                           -4.320
#
#       Minimum Degree  Molecular Weight  Number of H-Bond Donors  \
# ...
