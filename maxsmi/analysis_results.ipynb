# %% [markdown]
# # maxsmi
# ## Analysis of results
#
# This notebook serves to analyse the results of the simulations ran on the Curta cluster.
#
# ## Prerequisites
# This notebook will run under the condition that some simulations have been run, e.g.
# ```
# (maxsmi) $ python maxsmi/full_workflow.py --task ESOL --aug-strategy-train augmentation_with_duplication --aug-nb-train 10 --aug-nb-test 10
#
# ```
#
# Have a look at the [README](https://github.com/t-kimber/maxsmi/blob/main/README.md) page for more details.

# %% [raw]
# #!pip install flake8 pycodestyle_magic
# %load_ext pycodestyle_magic
# %pycodestyle_on

# %% [raw]
# %load_ext autoreload
# %autoreload 2

# %%
from maxsmi.utils_analysis import (load_data,
                                   plot_loss,
                                   retrieve_metric,
                                   plot_metric)

# %% [markdown]
# Let's have a quick look at this particular example.

# %%
TASK = "ESOL"
STRING_ENCODING = "smiles"
TRAIN_AUGMENTATION = 100
TEST_AUGMENTATION = 100
AUGMENTATION_STRATEGY_TRAIN = "augmentation_with_duplication"
AUGMENTATION_STRATEGY_TEST = "augmentation_with_duplication"
ML_MODEL = "CONV1D"

# %%
data = load_data(TASK,
                 AUGMENTATION_STRATEGY_TRAIN,
                 TRAIN_AUGMENTATION,
                 AUGMENTATION_STRATEGY_TEST,
                 TEST_AUGMENTATION,
                 ML_MODEL,
                 STRING_ENCODING)

# %%
data.head()
# Out:
#                execution          time_training           time_testing  \
# 0 0 days 02:42:17.335085 0 days 02:40:07.805108 0 days 00:00:23.029876
#
#                                                 loss  \
# 0  [0.07979393717471485, 0.03854445398266855, 0.0...
#
#                                           train  \
# 0  (0.005517431, 0.07427941, 0.998739518330024)
#
#                                                 test
# 0  (0.3558095257790578, 0.5964977164910673, 0.919...

# %%
plot_loss(AUGMENTATION_STRATEGY_TRAIN,
          TRAIN_AUGMENTATION,
          AUGMENTATION_STRATEGY_TEST,
          TEST_AUGMENTATION)

# %%
plot_metric("r2", "test", "augmentation_with_duplication")
# Out:
# ESOL;CONV1D 	max value: 0.93,	 80
# ESOL;CONV2D 	max value: 0.91,	 20
# ESOL;RNN 	max value: 0.92,	 70
# free_solv;CONV1D 	max value: 0.94,	 70
# free_solv;CONV2D 	max value: 0.88,	 60
# free_solv;RNN 	max value: 0.93,	 70

# %%
plot_metric("time", "train", "augmentation_with_duplication")
# Out:
# ESOL;CONV1D, 	max value: 71.00,	 0
# ESOL;CONV2D, 	max value: 83.00,	 0
# ESOL;RNN, 	max value: 122.00,	 0
# free_solv;CONV1D, 	max value: 41.00,	 0
# free_solv;CONV2D, 	max value: 45.00,	 0
# free_solv;RNN, 	max value: 57.00,	 0

# %%
plot_metric("mse", "train", "augmentation_with_duplication")
# Out:
# ESOL;CONV1D, 	max value: 0.01,	 100
# ESOL;CONV2D, 	max value: 0.01,	 80
# ESOL;RNN, 	max value: 0.05,	 90
# free_solv;CONV1D, 	max value: 0.01,	 90
# free_solv;CONV2D, 	max value: 0.01,	 100
# free_solv;RNN, 	max value: 0.04,	 90

# %%
plot_metric("rmse", "test", "augmentation_with_duplication")
# Out:
# ESOL;CONV1D, 	max value: 0.57,	 80
# ESOL;CONV2D, 	max value: 0.64,	 20
# ESOL;RNN, 	max value: 0.59,	 70
# free_solv;CONV1D, 	max value: 1.03,	 70
# free_solv;CONV2D, 	max value: 1.43,	 60
# free_solv;RNN, 	max value: 1.11,	 70
